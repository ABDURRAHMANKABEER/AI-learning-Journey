# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 📚 Today's Learning: Handling Missing Data
# ## 🧠 Step 1: Understand What "Missing Data" Means
# In Python (pandas), missing values are usually represented as:
#
# NaN (Not a Number)
# None

# %%
df = pd.read_csv('./data/my_file.csv')
df
# Out:
#     Rank   Peak All Time Peak     Actual gross  \
# 0      1      1             2     $780,000,000
# 1      2      1          7[2]     $579,800,000
# 2      3   1[4]          2[5]     $411,000,000
# 3      4   2[7]         10[7]     $397,300,000
# 4      5   2[4]           NaN     $345,675,146
# 5      6   2[4]         10[9]     $305,158,363
# 6      7  2[10]           NaN     $280,000,000
# 7      7    NaN           NaN     $257,600,000
# 8      9    NaN           NaN     $256,084,556
# 9     10    NaN           NaN     $250,400,000
# 10    11    NaN           NaN  $229,100,000[b]
# 11    12    NaN        14[17]     $227,400,000
# 12    13    NaN           NaN     $204,000,000
# 13    14  1[20]           NaN     $200,000,000
# 14    15   2[c]           NaN     $194,000,000
# 15    16    NaN           NaN     $184,000,000
# 16    17    NaN           NaN     $170,000,000
# 17    18    NaN           NaN     $169,800,000
# 18    19    NaN           NaN  $167,700,000[e]
# ...

# %%
#check for missing data
print(df.isnull().sum())
# Out:
# Rank                                 0
# Peak                                11
# All Time Peak                       14
# Actual gross                         0
# Adjusted gross (in 2022 dollars)     0
# Artist                               0
# Tour title                           0
# Year(s)                              0
# Shows                                0
# Average gross                        0
# Ref.                                 0
# dtype: int64

# %% [markdown]
# # 🔧 Step 3: Techniques to Handle Missing Data
# 1. Drop Rows or Columns
# Use when the data is mostly missing or not important.

# %%
df_cleaned = df.dropna()
df_cleaned
# Out:
#    Rank  Peak All Time Peak  Actual gross Adjusted gross (in 2022 dollars)  \
# 0     1     1             2  $780,000,000                     $780,000,000
# 1     2     1          7[2]  $579,800,000                     $579,800,000
# 2     3  1[4]          2[5]  $411,000,000                     $560,622,615
# 3     4  2[7]         10[7]  $397,300,000                     $454,751,555
# 5     6  2[4]         10[9]  $305,158,363                     $388,978,496
#
#          Artist                   Tour title    Year(s)  Shows Average gross  \
# 0  Taylor Swift              The Eras Tour †  2023–2024     56   $13,928,571
# 1       Beyoncé       Renaissance World Tour       2023     56   $10,353,571
# 2       Madonna  Sticky & Sweet Tour ‡[4][a]  2008–2009     85    $4,835,294
# 3          Pink  Beautiful Trauma World Tour  2018–2019    156    $2,546,795
# 5       Madonna                The MDNA Tour       2012     88    $3,467,709
#
#   Ref.
# 0  [1]
# 1  [3]
# 2  [6]
# 3  [7]
# 5  [9]

# %% [markdown]
# # 2. Fill with a Default Value
# Use when it makes sense to replace missing with 0 or "Unknown"

# %%
df['All Time Peak'] = df['All Time Peak'].fillna('Unknown')
df['Peak'] = df['Peak'].fillna('Unknown')
df
# Out:
#     Rank     Peak All Time Peak     Actual gross  \
# 0      1        1             2     $780,000,000
# 1      2        1          7[2]     $579,800,000
# 2      3     1[4]          2[5]     $411,000,000
# 3      4     2[7]         10[7]     $397,300,000
# 4      5     2[4]       Unknown     $345,675,146
# 5      6     2[4]         10[9]     $305,158,363
# 6      7    2[10]       Unknown     $280,000,000
# 7      7  Unknown       Unknown     $257,600,000
# 8      9  Unknown       Unknown     $256,084,556
# 9     10  Unknown       Unknown     $250,400,000
# 10    11  Unknown       Unknown  $229,100,000[b]
# 11    12  Unknown        14[17]     $227,400,000
# 12    13  Unknown       Unknown     $204,000,000
# 13    14    1[20]       Unknown     $200,000,000
# 14    15     2[c]       Unknown     $194,000,000
# 15    16  Unknown       Unknown     $184,000,000
# 16    17  Unknown       Unknown     $170,000,000
# 17    18  Unknown       Unknown     $169,800,000
# ...

# %%
cleaned_data = df.to_csv('./data/cleaned_data.csv', index=False)

# %% [markdown]
# ### 🧹 Data Cleaning Notes
#
# - **Column**: All Time peak
#   - Missing Count: 14
#   - Method Used: `fillna('Unknown')`
#   - Reason: It contain value and the values are not predictable, and we don’t want to drop rows yet.
#
# - **Column**: Peak
#   - Missing Count: 11
#   - Method Used: `fillna('Unknown')`
#   - Reason: Same as All Time Peak
